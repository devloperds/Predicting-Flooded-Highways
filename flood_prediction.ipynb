# %% [markdown]
# # FLOODS PREDICTION

# %% [markdown]
# ![](https://images.hindustantimes.com/rf/image_size_630x354/HT/p2/2020/08/17/Pictures/weather-rain-in-warangal_d9fc8040-e00a-11ea-a97c-4447400c36de.jpg)

# %% [markdown]
# # IMPORTING THE LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import scipy as sp
import warnings
import datetime
warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# # LOADING THE DATASET

# %%
data=pd.read_csv("Historic_Flood.xlsx.csv")

# %%
data
# Out:
#              DATE                                      AREA             CODE  \
# 0      31/01/2006                                SW - Devon        113WACT2a
# 1      31/01/2006                         SW - North Wessex       112WACTAVN
# 2      08/02/2006                             ANG - Eastern        054WATBT1
# 3      08/02/2006                             ANG - Eastern        054WATBT2
# 4      08/02/2006                             ANG - Eastern        054WATBT3
# ...           ...                                       ...              ...
# 58774  31/03/2021                 Gtr Mancs Mersey and Ches        013WATMEW
# 58775  31/03/2021  East Anglia - Essex, Norfolk and Suffolk       051WACDV4C
# 58776  31/03/2021                            Wessex - North       112WATSOM1
# 58777  31/03/2021                Kent S London and E Sussex     063WAT23West
# 58778  31/03/2021                Kent S London and E Sussex  063WAT23Central
#
#                                WARNING / ALERT AREA NAME                TYPE
# 0                                    Devon Coast (North)         Flood Watch
# 1                                   Porlock to Avonmouth         Flood Watch
# 2                      Tidal Rivers Bure, Ant and Thurne         Flood Watch
# 3                                       Tidal River Yare         Flood Watch
# 4                                    Tidal River Waveney         Flood Watch
# ...                                                  ...                 ...
# 58774                       Mersey Estuary at Warrington  Update Flood Alert
# 58775  The Essex coast from Clacton to and including,...         Flood Alert
# 58776                     Somerset coast at Porlock Weir  Update Flood Alert
# 58777  Tidal Thames riverside from Putney Bridge to T...  Update Flood Alert
# 58778  Tidal Thames riverside from the Thames Barrier...         Flood Alert
#
# [58779 rows x 5 columns]

# %%
data.describe()
# Out:
#               DATE                           AREA       CODE  \
# count        58779                          58779      58779
# unique        3006                             49       4083
# top     09/02/2020  NE - Yorkshire North and East  122WAC954
# freq           478                           3566        645
#
#              WARNING / ALERT AREA NAME         TYPE
# count                            58779        58779
# unique                            4516            7
# top     North Sea Coast at Bridlington  Flood Alert
# freq                               658        29090

# %%
data.info
# Out:
# <bound method DataFrame.info of              DATE                                      AREA             CODE  \
# 0      31/01/2006                                SW - Devon        113WACT2a
# 1      31/01/2006                         SW - North Wessex       112WACTAVN
# 2      08/02/2006                             ANG - Eastern        054WATBT1
# 3      08/02/2006                             ANG - Eastern        054WATBT2
# 4      08/02/2006                             ANG - Eastern        054WATBT3
# ...           ...                                       ...              ...
# 58774  31/03/2021                 Gtr Mancs Mersey and Ches        013WATMEW
# 58775  31/03/2021  East Anglia - Essex, Norfolk and Suffolk       051WACDV4C
# 58776  31/03/2021                            Wessex - North       112WATSOM1
# 58777  31/03/2021                Kent S London and E Sussex     063WAT23West
# 58778  31/03/2021                Kent S London and E Sussex  063WAT23Central
#
#                                WARNING / ALERT AREA NAME                TYPE
# 0                                    Devon Coast (North)         Flood Watch
# 1                                   Porlock to Avonmouth         Flood Watch
# 2                      Tidal Rivers Bure, Ant and Thurne         Flood Watch
# 3                                       Tidal River Yare         Flood Watch
# 4                                    Tidal River Waveney         Flood Watch
# ...                                                  ...                 ...
# 58774                       Mersey Estuary at Warrington  Update Flood Alert
# 58775  The Essex coast from Clacton to and including,...         Flood Alert
# 58776                     Somerset coast at Porlock Weir  Update Flood Alert
# 58777  Tidal Thames riverside from Putney Bridge to T...  Update Flood Alert
# 58778  Tidal Thames riverside from the Thames Barrier...         Flood Alert
#
# [58779 rows x 5 columns]>

# %%
data.var()
# Out:
# Series([], dtype: float64)

# %%
data.shape
# Out:
# (58779, 5)

# %%
data.dtypes
# Out:
# DATE                         object
# AREA                         object
# CODE                         object
# WARNING / ALERT AREA NAME    object
# TYPE                         object
# dtype: object

# %% [markdown]
# **Checking Null Values**

# %%
data.isnull().sum()
# Out:
# DATE                         0
# AREA                         0
# CODE                         0
# WARNING / ALERT AREA NAME    0
# TYPE                         0
# dtype: int64

# %%
data.columns
# Out:
# Index(['DATE', 'AREA', 'CODE', 'WARNING / ALERT AREA NAME', 'TYPE'], dtype='object')

# %%
data.isnull().any()
# Out:
# DATE                         False
# AREA                         False
# CODE                         False
# WARNING / ALERT AREA NAME    False
# TYPE                         False
# dtype: bool

# %%
data.value_counts()
# Out:
# DATE        AREA               CODE              WARNING / ALERT AREA NAME                                                                    TYPE
# 03/03/2007  MID - East         034WAF402         River Soar in Leicestershire                                                                 Flood Watch      8
# 25/06/2007  MID - East         034WAF409         Lower Derwent in Derbyshire                                                                  Flood Watch      7
# 16/01/2008  MID - East         034WAF402         River Soar in Leicestershire                                                                 Flood Watch      4
# 08/12/2007  SW - North Wessex  112FWF3C1C        River Isle from Chard Reservoir to Hambridge                                                 Flood Warning    4
# 03/12/2006  SW - South Wessex  111WATTWBYH1      West Bay                                                                                     Flood Watch      4
#                                                                                                                                                               ..
# 11/01/2017  ANG - Eastern      054WACDV4B        The Suffolk and Essex Coast from Felixstowe to Clacton including Orwell and Stour Estuaries  Flood Alert      1
#                                054WATBT1         Tidal Rivers Bure, Ant and Thurne                                                            Flood Alert      1
#                                054WATBT2         Tidal River Yare                                                                             Flood Alert      1
#                                054WATBT3         Tidal River Waveney                                                                          Flood Alert      1
# 31/12/2019  Thames             061WAF22Lambourn  River Lambourn and its tributaries from Upper Lambourn down to Newbury                       Flood Alert      1
# Length: 56753, dtype: int64

# %%
#lets find the categorialfeatures
list_1=list(data.columns)

# %%
list_cate=[]
for i in list_1:
    if data[i].dtype=='object':
        list_cate.append(i)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
for i in list_cate:
    data[i]=le.fit_transform(data[i])

# %%
data
# Out:
#        DATE  AREA  CODE  WARNING / ALERT AREA NAME  TYPE
# 0      2950    34  3017                        384     2
# 1      2950    35  2850                       1351     2
# 2       696     1  1568                       4139     2
# 3       696     1  1569                       4137     2
# 4       696     1  1570                       4134     2
# ...     ...   ...   ...                        ...   ...
# 58774  2973    10   442                       1036     4
# 58775  2973     8  1172                       3881     0
# 58776  2973    43  2875                       3743     4
# 58777  2973    12  2039                       4154     4
# 58778  2973    12  2037                       4155     0
#
# [58779 rows x 5 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %%
data.hist(figsize=(20,14))
plt.show()

# %%
plt.figure(figsize = (12,10))

sns.heatmap(data.corr(), annot =True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data=data)

# %%
plt.figure(figsize=(14,10))
sns.set_style(style='whitegrid')
plt.subplot(2,3,1)
sns.boxplot(x='DATE',data=data)
plt.subplot(2,3,2)
sns.boxplot(x='AREA',data=data)
plt.subplot(2,3,3)
sns.boxplot(x='CODE',data=data)
plt.subplot(2,3,4)
sns.boxplot(x='TYPE',data=data)
plt.subplot(2,3,5)
sns.boxplot(x='WARNING / ALERT AREA NAME',data=data)
# Out:
# <AxesSubplot:xlabel='WARNING / ALERT AREA NAME'>

# %%
sns.scatterplot(x='AREA', y= 'TYPE', data=data)
# Out:
# <AxesSubplot:xlabel='AREA', ylabel='TYPE'>

# %%
sns.kdeplot(x='CODE',y= 'AREA', data=data)
# Out:
# <AxesSubplot:xlabel='CODE', ylabel='AREA'>

# %%
sns.scatterplot(x='CODE', y= 'AREA', data=data)
# Out:
# <AxesSubplot:xlabel='CODE', ylabel='AREA'>

# %%
plt.figure(figsize=(14,10))
sns.set_style(style='whitegrid')
plt.subplot(2,3,1)
sns.violinplot(x='DATE',data=data)
plt.subplot(2,3,2)
sns.violinplot(x='AREA',data=data)
plt.subplot(2,3,3)
sns.violinplot(x='CODE',data=data)
plt.subplot(2,3,4)
sns.violinplot(x='TYPE',data=data)
plt.subplot(2,3,5)
sns.violinplot(x='WARNING / ALERT AREA NAME',data=data)
# Out:
# <AxesSubplot:xlabel='WARNING / ALERT AREA NAME'>

# %%
sns.lineplot(x='CODE', y= 'AREA', data=data)
# Out:
# <AxesSubplot:xlabel='CODE', ylabel='AREA'>

# %%
plt.figure(figsize=(14,10))
sns.set_style(style='whitegrid')
plt.subplot(2,3,1)
sns.boxplot(x='DATE',data=data)
plt.subplot(2,3,2)
sns.violinplot(x='AREA',data=data,color='pink')
plt.subplot(2,3,3)
sns.scatterplot(x='CODE',y='AREA',data=data,color='g')
plt.subplot(2,3,4)
sns.violinplot(x='TYPE',data=data)
plt.subplot(2,3,5)
sns.kdeplot(x='WARNING / ALERT AREA NAME',data=data,color='r')
# Out:
# <AxesSubplot:xlabel='WARNING / ALERT AREA NAME', ylabel='Density'>

# %%
sns.jointplot(x='CODE',y='AREA',data=data,color='blue')

# %%
plt.style.use("default")
plt.figure(figsize=(5,5))
sns.barplot(x="TYPE", y="CODE", data=data)
plt.title("TYPE vs CODE",fontsize=15)
plt.xlabel("TYPE")
plt.ylabel("CODE")
plt.show()

# %%
plt.style.use("default")
plt.figure(figsize=(5,5))
sns.barplot(x="TYPE", y="AREA", data=data)
plt.title("TYPE vs AREA",fontsize=15)
plt.xlabel("TYPE")
plt.ylabel("AREA")
plt.show()

# %%
plt.style.use("default")
plt.figure(figsize=(5,5))
sns.barplot(x="TYPE", y="WARNING / ALERT AREA NAME", data=data)
plt.title("TYPE vs WARNING / ALERT AREA NAME",fontsize=15)
plt.xlabel("TYPE")
plt.ylabel("WARNING / ALERT AREA NAME")
plt.show()

# %%
data.columns
# Out:
# Index(['DATE', 'AREA', 'CODE', 'WARNING / ALERT AREA NAME', 'TYPE'], dtype='object')

# %%
y=data['AREA']
x=data.drop('AREA',axis=1)

# %% [markdown]
# # TRAINING AND TESTING DATA

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0,test_size=0.2)

# %%
print(len(x_train))
print(len(x_test))
print(len(y_train))
print(len(y_test))
# Out:
# 47023
# 11756
# 47023
# 11756

# %% [markdown]
# # MODELS
# **1. KNeighborsClassifier**

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=7)

knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred=knn.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",knn.score(x_train,y_train)*100)
accuracy_score(y_test,y_pred)*100
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.73      0.69      0.71       160
#            1       0.79      0.82      0.81       548
#            2       0.54      0.63      0.58       174
#            3       0.57      0.46      0.51       212
#            4       0.54      0.42      0.47       133
#            5       0.48      0.54      0.51       151
#            6       0.42      0.29      0.34       167
#            7       0.64      0.58      0.61       111
#            8       0.77      0.86      0.81       228
#            9       0.60      0.47      0.53       227
#           10       0.57      0.50      0.53       133
#           11       0.41      0.44      0.42        68
#           12       0.54      0.52      0.53       254
#           13       0.49      0.27      0.34       135
#           14       0.63      0.63      0.63       379
#           15       0.58      0.70      0.63       276
#           16       0.66      0.49      0.57        79
#           17       0.62      0.77      0.69       508
#           18       0.72      0.74      0.73       232
#           19       0.73      0.81      0.77       730
#           20       0.81      0.82      0.81       305
#           21       0.67      0.79      0.72       232
#           22       0.81      0.88      0.84       603
#           23       0.59      0.54      0.57       164
#           24       0.46      0.25      0.33        91
#           25       0.43      0.51      0.47       142
#           26       0.42      0.38      0.40        79
#           27       0.60      0.73      0.66       363
#           28       0.46      0.53      0.49        70
#           29       0.54      0.67      0.60       264
#           30       0.74      0.85      0.79       113
#           31       0.87      0.77      0.82       145
#           32       0.39      0.24      0.30        46
#           33       0.64      0.63      0.63       262
#           34       0.72      0.81      0.76       485
#           35       0.72      0.81      0.76       582
#           36       0.69      0.83      0.75       425
#           37       0.59      0.48      0.53       284
#           38       0.44      0.36      0.40        44
#           39       0.93      0.59      0.72        95
#           40       0.97      0.71      0.82        52
#           41       0.81      0.74      0.77       190
#           42       0.49      0.40      0.44       190
#           43       0.48      0.29      0.36       233
#           44       0.48      0.30      0.37       189
#           45       0.54      0.55      0.55       284
#           46       0.54      0.39      0.45       319
#           47       0.59      0.53      0.56       416
#           48       0.72      0.63      0.67       184
#
#     accuracy                           0.65     11756
#    macro avg       0.62      0.58      0.59     11756
# weighted avg       0.65      0.65      0.64     11756
#
# Confusion Matrix:
#  [[111  14   2 ...   0   0   0]
#  [  3 448  11 ...   0   0   0]
#  [  2  30 109 ...   0   0   0]
#  ...
#  [  0   0   0 ... 126   0   0]
#  [  0   0   0 ...   0 219   0]
#  [  0   0   0 ...   0   3 116]]
# Training Score:
#  74.91653020862131
# 65.217761143246

# %% [markdown]
# **2. Naive Bayes**

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred=gnb.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",gnb.score(x_train,y_train)*100)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.79      0.36      0.49       160
#            1       0.42      0.39      0.41       548
#            2       0.26      0.18      0.22       174
#            3       0.46      0.08      0.14       212
#            4       0.60      0.30      0.40       133
#            5       0.69      0.22      0.33       151
#            6       0.55      0.04      0.07       167
#            7       0.64      0.56      0.60       111
#            8       0.36      0.83      0.50       228
#            9       0.55      0.53      0.54       227
#           10       0.68      0.27      0.39       133
#           11       0.50      0.07      0.13        68
#           12       0.70      0.18      0.29       254
#           13       0.00      0.00      0.00       135
#           14       0.57      0.73      0.64       379
#           15       0.42      0.52      0.47       276
#           16       0.97      0.80      0.88        79
#           17       0.29      0.11      0.16       508
#           18       0.62      0.87      0.72       232
#           19       0.66      0.94      0.78       730
#           20       0.68      0.76      0.72       305
#           21       0.63      0.77      0.70       232
#           22       0.72      0.91      0.81       603
#           23       0.55      0.77      0.64       164
#           24       0.56      0.11      0.18        91
#           25       0.40      0.87      0.55       142
#           26       0.53      0.85      0.65        79
#           27       0.67      0.79      0.72       363
#           28       0.52      1.00      0.69        70
#           29       0.57      0.81      0.67       264
#           30       0.96      0.88      0.92       113
#           31       0.99      0.90      0.94       145
#           32       0.67      0.93      0.78        46
#           33       0.61      0.86      0.72       262
#           34       0.70      0.91      0.79       485
#           35       0.69      0.84      0.76       582
#           36       0.60      1.00      0.75       425
#           37       0.79      0.51      0.62       284
#           38       0.70      0.84      0.76        44
#           39       0.96      0.80      0.87        95
#           40       0.98      0.87      0.92        52
#           41       0.95      0.89      0.92       190
#           42       0.67      0.14      0.23       190
#           43       0.68      0.23      0.35       233
#           44       0.00      0.00      0.00       189
#           45       0.53      0.32      0.40       284
#           46       0.41      0.92      0.57       319
#           47       0.75      0.21      0.33       416
#           48       0.61      0.25      0.36       184
#
#     accuracy                           0.60     11756
#    macro avg       0.61      0.57      0.54     11756
# weighted avg       0.60      0.60      0.56     11756
#
# Confusion Matrix:
#  [[ 57  37   0 ...   0   0   0]
#  [  0 215  68 ...   0   0   0]
#  [  0 101  32 ...   0   0   0]
#  ...
#  [  0   0   0 ... 293   0   0]
#  [  0   0   0 ...   0  89   0]
#  [  0   0   0 ...   0   4  46]]
# Training Score:
#  60.7107160325798

# %%
accuracy_score(y_test,y_pred)*100
# Out:
# 60.148009527050014

# %% [markdown]
# **3. DECISION TREE CLASSIFIER**

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier(max_depth=6, random_state=123,criterion='entropy')

dtree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=6, random_state=123)

# %%
y_pred=dtree.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",dtree.score(x_train,y_train)*100)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.59      1.00      0.74       160
#            1       0.61      1.00      0.76       548
#            2       0.54      0.59      0.57       174
#            3       0.86      0.15      0.25       212
#            4       1.00      0.18      0.31       133
#            5       0.89      0.22      0.35       151
#            6       0.66      0.11      0.19       167
#            7       0.00      0.00      0.00       111
#            8       0.00      0.00      0.00       228
#            9       0.58      1.00      0.74       227
#           10       0.88      0.26      0.40       133
#           11       0.86      0.09      0.16        68
#           12       0.00      0.00      0.00       254
#           13       0.00      0.00      0.00       135
#           14       0.70      0.34      0.46       379
#           15       1.00      0.41      0.58       276
#           16       1.00      1.00      1.00        79
#           17       0.65      1.00      0.79       508
#           18       0.74      0.96      0.83       232
#           19       0.69      0.98      0.81       730
#           20       0.69      0.82      0.75       305
#           21       0.68      1.00      0.81       232
#           22       0.77      0.99      0.87       603
#           23       0.62      0.97      0.76       164
#           24       0.55      0.13      0.21        91
#           25       0.43      1.00      0.60       142
#           26       0.54      0.99      0.70        79
#           27       0.70      0.90      0.79       363
#           28       0.50      1.00      0.67        70
#           29       0.57      0.92      0.70       264
#           30       0.69      1.00      0.82       113
#           31       1.00      0.97      0.99       145
#           32       0.00      0.00      0.00        46
#           33       0.69      0.98      0.81       262
#           34       0.76      0.98      0.86       485
#           35       0.76      1.00      0.86       582
#           36       0.69      1.00      0.82       425
#           37       0.80      0.51      0.62       284
#           38       1.00      0.89      0.94        44
#           39       1.00      0.94      0.97        95
#           40       0.89      0.92      0.91        52
#           41       1.00      0.93      0.96       190
#           42       0.48      0.11      0.17       190
#           43       1.00      0.20      0.33       233
#           44       0.00      0.00      0.00       189
#           45       0.48      0.81      0.60       284
#           46       1.00      0.16      0.27       319
#           47       0.89      0.21      0.34       416
#           48       0.57      0.40      0.47       184
#
#     accuracy                           0.69     11756
#    macro avg       0.65      0.61      0.56     11756
# weighted avg       0.67      0.69      0.62     11756
#
# Confusion Matrix:
#  [[160   0   0 ...   0   0   0]
#  [  0 548   0 ...   0   0   0]
#  [  0  71 103 ...   0   0   0]
#  ...
#  [  0   0   0 ...  50   0   0]
#  [  0   0   0 ...   0  89   0]
#  [  0   0   0 ...   0   0  73]]
# Training Score:
#  69.22357144376157

# %%
accuracy_score(y_test,y_pred)*100
# Out:
# 68.62027900646478

# %%
data = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
data
# Out:
#        Actual  Predicted
# 28490      27         37
# 41369      47         19
# 51309      44         36
# 10300      34         34
# 26631      27         27
# ...       ...        ...
# 16034       0          0
# 52933      46         17
# 14758      35         35
# 21421      17         17
# 56450      47         19
#
# [11756 rows x 2 columns]

# %% [markdown]
# **4.Random Forest Classifier**

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=rfc.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",rfc.score(x_train,y_train)*100)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91       160
#            1       1.00      0.99      1.00       548
#            2       0.72      0.80      0.76       174
#            3       0.70      0.69      0.70       212
#            4       0.80      0.73      0.76       133
#            5       0.62      0.59      0.61       151
#            6       0.56      0.55      0.56       167
#            7       0.85      0.86      0.86       111
#            8       0.98      1.00      0.99       228
#            9       0.69      0.66      0.67       227
#           10       0.71      0.71      0.71       133
#           11       0.60      0.59      0.59        68
#           12       0.76      0.70      0.73       254
#           13       0.70      0.59      0.64       135
#           14       0.75      0.77      0.76       379
#           15       0.73      0.75      0.74       276
#           16       1.00      1.00      1.00        79
#           17       0.78      0.82      0.80       508
#           18       0.83      0.82      0.82       232
#           19       0.88      0.86      0.87       730
#           20       0.88      0.92      0.90       305
#           21       0.85      0.90      0.87       232
#           22       0.89      0.90      0.89       603
#           23       0.77      0.77      0.77       164
#           24       0.56      0.58      0.57        91
#           25       0.76      0.81      0.78       142
#           26       0.65      0.62      0.64        79
#           27       0.79      0.87      0.83       363
#           28       0.48      0.56      0.51        70
#           29       0.66      0.71      0.69       264
#           30       0.90      0.96      0.93       113
#           31       0.99      0.99      0.99       145
#           32       0.87      0.72      0.79        46
#           33       0.77      0.79      0.78       262
#           34       0.85      0.85      0.85       485
#           35       0.83      0.83      0.83       582
#           36       0.85      0.87      0.86       425
#           37       0.81      0.70      0.75       284
#           38       0.78      0.91      0.84        44
#           39       0.98      0.98      0.98        95
#           40       1.00      0.92      0.96        52
#           41       0.98      0.96      0.97       190
#           42       0.57      0.52      0.54       190
#           43       0.57      0.57      0.57       233
#           44       0.70      0.67      0.68       189
#           45       0.68      0.65      0.66       284
#           46       0.69      0.64      0.66       319
#           47       0.76      0.79      0.77       416
#           48       0.86      0.79      0.82       184
#
#     accuracy                           0.80     11756
#    macro avg       0.78      0.78      0.78     11756
# weighted avg       0.80      0.80      0.80     11756
#
# Confusion Matrix:
#  [[145   0   0 ...   0   0   0]
#  [  0 545   0 ...   0   0   0]
#  [  0   0 139 ...   0   0   0]
#  ...
#  [  0   0   0 ... 205   0   0]
#  [  0   0   0 ...   0 327   0]
#  [  0   0   0 ...   0   0 145]]
# Training Score:
#  99.99574676222274

# %%
accuracy_score(y_test,y_pred)*100
# Out:
# 79.83157536577068

# %%
data.columns
# Out:
# Index(['Actual', 'Predicted'], dtype='object')

# %% [markdown]
# **5. ExtraTreesClassifier**

# %%
from sklearn.ensemble import ExtraTreesClassifier
etc = ExtraTreesClassifier(n_estimators=100, random_state=0)
etc.fit(x_train,y_train)
# Out:
# ExtraTreesClassifier(random_state=0)

# %%
y_pred=etc.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",etc.score(x_train,y_train)*100)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89       160
#            1       0.99      0.99      0.99       548
#            2       0.71      0.77      0.74       174
#            3       0.61      0.64      0.63       212
#            4       0.80      0.71      0.75       133
#            5       0.58      0.55      0.57       151
#            6       0.53      0.56      0.54       167
#            7       0.84      0.85      0.84       111
#            8       0.97      0.99      0.98       228
#            9       0.67      0.64      0.66       227
#           10       0.72      0.69      0.70       133
#           11       0.57      0.56      0.56        68
#           12       0.76      0.70      0.73       254
#           13       0.67      0.59      0.63       135
#           14       0.71      0.72      0.72       379
#           15       0.72      0.75      0.73       276
#           16       1.00      1.00      1.00        79
#           17       0.75      0.79      0.77       508
#           18       0.83      0.78      0.80       232
#           19       0.86      0.85      0.86       730
#           20       0.88      0.91      0.89       305
#           21       0.85      0.90      0.87       232
#           22       0.87      0.86      0.86       603
#           23       0.76      0.78      0.77       164
#           24       0.51      0.58      0.54        91
#           25       0.77      0.84      0.80       142
#           26       0.64      0.62      0.63        79
#           27       0.79      0.84      0.81       363
#           28       0.48      0.56      0.51        70
#           29       0.67      0.69      0.68       264
#           30       0.90      0.96      0.93       113
#           31       0.99      0.99      0.99       145
#           32       0.86      0.70      0.77        46
#           33       0.75      0.77      0.76       262
#           34       0.84      0.83      0.84       485
#           35       0.81      0.80      0.81       582
#           36       0.85      0.87      0.86       425
#           37       0.78      0.71      0.74       284
#           38       0.82      0.91      0.86        44
#           39       1.00      0.98      0.99        95
#           40       1.00      0.92      0.96        52
#           41       0.97      0.96      0.97       190
#           42       0.55      0.53      0.54       190
#           43       0.53      0.54      0.53       233
#           44       0.70      0.67      0.68       189
#           45       0.62      0.61      0.62       284
#           46       0.63      0.58      0.60       319
#           47       0.74      0.76      0.75       416
#           48       0.84      0.79      0.81       184
#
#     accuracy                           0.78     11756
#    macro avg       0.77      0.76      0.76     11756
# weighted avg       0.78      0.78      0.78     11756
#
# Confusion Matrix:
#  [[142   0   0 ...   0   0   0]
#  [  0 543   0 ...   0   0   0]
#  [  0   1 134 ...   0   0   0]
#  ...
#  [  0   0   0 ... 185   0   0]
#  [  0   0   0 ...   0 318   0]
#  [  0   0   0 ...   0   0 145]]
# Training Score:
#  100.0

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7808778496087104

# %% [markdown]
# **6.Bagging Classifier**

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn import tree
model = BaggingClassifier(tree.DecisionTreeClassifier(random_state=1))
model.fit(x_train, y_train)
model.score(x_test,y_test)
# Out:
# 0.8734263354882613

# %%
data = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
data
# Out:
#        Actual  Predicted
# 28490      27         27
# 41369      47         19
# 51309      44         44
# 10300      34         34
# 26631      27         27
# ...       ...        ...
# 16034       0          0
# 52933      46         46
# 14758      35         43
# 21421      17         17
# 56450      47         47
#
# [11756 rows x 2 columns]

# %% [markdown]
# # CONCLUSION :
#
# **ACCURACIES OF DIFFERENT MODELS ARE:**
#
# **KNeighbors Classifier= 65.21 %**
#
# **Naiye Bayes= 60.10 %**
#
# **Decision Tree Classifier= 68.62 %**
#
# **Random Forest Classifier= 79.97 %**
#
# **Extra Trees Classifier= 78.80 %**
#
# **Bagging Classifier = 87.34 %**
#
# **We got a good accuracy of about 88 % using Bagging Classifier which is quite well for the given dataset.**
#
# **The accuracy of other models can be increased further by HyperTuning.**
